# %% [markdown]
# ## 高德

# %% [markdown]
# ### 地理编码

# %%
import json
import requests
from pprint import pprint
import logging
logger = logging.getLogger("root")
logger.setLevel(logging.INFO)

def load_dict():
    LOC_DICT = json.load(open("loc_dict.json"))
    DIS_DICT = json.load(open("dis_dict.json"))
    print(LOC_DICT, DIS_DICT)
    
def dump_dict():
    json.dump(LOC_DICT, open("loc_dict.json", "w"), ensure_ascii=False, indent=2)
    json.dump(DIS_DICT, open("dis_dict.json", "w"), ensure_ascii=False, indent=2)

KEY = '33e2719dbf39acaf016591b2e6786052'
CITY = "北京" # speicfy city, otherwise search the whole country
TARGET_ADDRESS = "源创空间大厦"

LOC_DICT = DIS_DICT = {}
load_dict()
# Out:
# {'朝阳大悦城': '116.523365,39.923063', '源创空间大厦': '116.506470,39.902120', '姚家园东里7号院': '116.518627,39.945863', '扬州水乡别墅': '116.570957,39.852185', '通惠家园惠生园': '116.508111,39.909585', '石门新居': '116.347152,39.891967', '龙跃苑东五区': '116.356823,40.072324', '空军大院': '116.330807,40.057551', '康家园': '116.517304,39.911124', '金隅翡丽铂爵郡': '116.372886,40.065132', '金顶街四区': '116.173015,39.925170', '建清园小区': '116.347789,40.015794', '佳运园二区': '116.401943,40.046257', '慧谷时空': '116.470847,40.002795', '和谐家园二区': '116.360358,40.082532', '高档小区榴景秀苑27号楼': '116.422704,39.844279', '富力阳光美园': '116.606466,39.927837', '方舟苑': '116.465574,39.980322', '东方雅苑小区': '116.474849,39.887748', '北花园小区': '116.550101,39.904687', '广通小区': '116.637081,39.901193', '花家地西里1区': '116.460162,39.988340', '老街西里小区': '116.375838,39.855286', '二里庄小区45号楼': '116.366718,39.993796', '延静里中街小区': '116.483779,39.916279', '永乐西小区': '116.226403,39.901519', '满庭芳嘉园': '116.546618,40.084657', '双花园南里': '116.454510,39.898911', '郎辛庄': '116.569842,39.856280', '羊毛胡同': '116.388983,39.902412', '慧华苑': '116.315535,40.076851', '望京西园一区': '116.475924,40.004494', '国门智慧城': '116.465180,39.895122', '南湖中园小区': '116.459884,39.999041', '龙博苑二区': '116.342215,40.069093', '珠江帝景': '116.479417,39.888755', '马公庄6号': '116.408981,39.856089', '远洋一方林语苑': '116.603156,39.898079', '东洲家园': '116.461663,40.045950', '八里庄北里1号院': '116.500233,39.923614', '\n玺萌鹏苑2号院': '116.407387,39.904179', '天通西苑三区': '116.409424,40.077062', '杨庄小区': '116.197347,39.918340', '康营家园': '116.540852,40.033237', '华威北里': '116.458180,39.878648', '望京西园四区': '116.471228,39.996755', '钢研社区': '116.336798,39.950092', '鸿博家园二期C区': '116.465407,39.829527', '中国农机院': '116.374180,40.001877', '荟康苑': '116.584507,39.918493', '三间房南里七号院乐乎公寓': '116.567172,39.910080', '望花路西里': '116.470770,39.989975', '百荣嘉园': '116.394764,39.866387', '唐家岭t09小区': '116.277505,40.066784', '田村48号院': '116.256673,39.929009', '康泽园小区二期': '116.409265,39.842121', '鸿博家园二期': '116
# %%
def get_add_loc(address: str):
#     logging.info(f"getting address of <{address}>")
    if address not in LOC_DICT:
        logging.info(f"fetching loc of {address} from gaode api")
        res = requests.get('https://restapi.amap.com/v3/geocode/geo', params={
            "key": KEY,
            "city": CITY,
            "address": address,
        })

        assert res.status_code == 200
        result = res.json()
        count = int(result.get('count', 0))
        if count == 0:
            logging.error("should have result")
            logging.error(result)
            LOC_DICT[address] = None
        else:
            if count > 1:
                logging.warning("more than 1 result, select the first")
            loc = result["geocodes"][0]["location"]
            LOC_DICT[address] = loc
        
    return LOC_DICT[address]

# %% [markdown]
# ### 通勤规划

# %%
def calc_walking_dis(from_address, to_address):
    logging.info(f"calc_walking_dis: from_address: {from_address}, to_address: {to_address}")
    res = requests.get('https://restapi.amap.com/v3/direction/walking',
                   params={
                       "key": KEY,
                       "origin": get_add_loc(from_address),
                       "destination": get_add_loc(to_address),
                       "output": "json",
                   })
    result = res.json()
    count = int(result.get("count", 0))
    if count == 0:
        logging.warning("not found any walking solution")
        logging.warning(result)
        return -1
    return int(float(result["route"]["paths"][0]["duration"]) / 60) # minutes  

def calc_transit_dis(from_address, to_address):
    key = from_address + "-" + to_address
    if key not in DIS_DICT:
        logging.info(f"calc_work_dis: from_address: {from_address}, to_address: {to_address}")
        from_loc = get_add_loc(from_address)
        to_loc = get_add_loc(to_address)
        if not to_loc:
            raise Exception("to loc must exist")
        if not from_loc:
            DIS_DICT[key] = 999
        else:
            res = requests.get('https://restapi.amap.com/v3/direction/transit/integrated',
                           params={
                               "origin": from_loc,
                               "destination": to_loc,
                               "output": "json",
                               "key": KEY,
                               "strategy": 3, # 0：最快捷模式, 1：最经济模式, 2：最少换乘模式, 3：最少步行模式, 5：不乘地铁模式
                               "extensions": "base",
                               "city": CITY
                           })
            result = res.json()
            count = int(result.get("count", 0))
            if count == 0:
                logging.info("not found any transit solution, trying walking ones")
                logging.info(result)
                DIS_DICT[key] = calc_walking_dis(from_address, to_address)
            else:
                DIS_DICT[key] = int(float(result["route"]["transits"][0]["duration"]) / 60) # minutes
    return DIS_DICT[key]

# %% [markdown]
# ## analyze rent sheet from some wechat group

# %%
import pandas as pd

# %% [markdown]
# ### read excel

# %%
df_raw = pd.read_excel("./北漂租房登记（表二）.xlsx")
df_raw
# Out:
#     求整租／求合租       居室           区域       居室.1                   一居室 步梯／电梯  \
# 0        房东       整租           朝阳       富华家园                   一居室    电梯
# 1       NaN      NaN          NaN        NaN                   NaN   NaN
# 2       NaN      NaN          NaN        NaN                   NaN   NaN
# 3       NaN  你还挺逗的啊！          NaN        NaN                   NaN   NaN
# 4       NaN      NaN          NaN        NaN                   NaN   NaN
# ..      ...      ...          ...        ...                   ...   ...
# 122      房东       合租  1号线管庄京通苑7号楼        京通苑  98平三居室(主卧带阳台)全女生，无隔断    电梯
# 123      转租       整租       7号线达官营   西城区天宁寺西里                 正规两居室    楼梯
# 124      转租       合租     望京西站13号线       香颂3期                正规次卧朝阳    电梯
# 125      转租       合租       8号线平西府   田园风光雅园东区             正规次卧，四室两卫    楼梯
# 126      整租      NaN        6号线常营  朝阳北小街北辰福地                  85平米    电梯
#
#          楼层                 登记时间         预算               联系方式  \
# 0    24楼19层                 登记日期         价位               联系方式
# 1       NaN                  NaN        NaN                NaN
# 2       NaN                  NaN        NaN                NaN
# 3       NaN                  NaN        NaN                NaN
# 4       NaN                  NaN        NaN                NaN
# ..      ...                  ...        ...                ...
# 122      2层  2022-03-01 00:00:00  2000/2500   grace304874709微信
# 123      5层  2022-03-01 00:00:00       5200      15001111201微信
# 124     10层  2022-03-02 00:00:00  2700-3000    15801260086微信同步
# 125      6层  2022-03-02 00:00:00       1900          S_pxy99_R
# 126      20  2022-03-02 00:00:00        NaN                NaN
#
#                                                     备注 Unnamed: 11
# 0                                                   备注         NaN
# 1                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3                                                  NaN         NaN
# 4                                                  NaN         NaN
# ..                                                 ...         ...
# 122                     押一付一，全职妈妈房东直租，无中介费，可以看各种证件，好沟通         NaN
# 123                      押一付三，转租，余14个月，无中介费，如有需要可与房东直签         NaN
# 124              个人转租，房子新，装修精，个人刚租交完中介费、服务费。便宜转租，只需交租金         NaN
# 125  在地铁站一二百米的位置，1900一个月。已和房东商议好不要中介费，到期🉑️和直接与房东续签。...         NaN
# 126                                                NaN         NaN
#
# [127 rows x 12 columns]

# %% [markdown]
# ### drop specific nan

# %%
df = df_raw.dropna(subset=["联系方式", "预算", "区域"])
columns = list(filter(lambda x: not x.startswith("Unnamed"), df.columns))
df = df[columns]
df
# Out:
#     求整租／求合租     居室              区域       居室.1                   一居室 步梯／电梯  \
# 0        房东     整租              朝阳       富华家园                   一居室    电梯
# 7        转租     合租         西二旗邓庄南路   唐家岭t09小区                    次卧    电梯
# 8        转租  整租一居室            通州梨园      海棠湾小区                 正规一居室    电梯
# 9        转租     合租  距离6号线田村地铁站269米     田村48号院     单间，正规三居室，其他两间都是女生    步梯
# 10       转租     合租           八通线附近     玉桥北里小区                    次卧    步梯
# ..      ...    ...             ...        ...                   ...   ...
# 121      房东     整租       朝阳区东坝锦安家园  朝阳区东坝锦安家园                   三居室    电梯
# 122      房东     合租     1号线管庄京通苑7号楼        京通苑  98平三居室(主卧带阳台)全女生，无隔断    电梯
# 123      转租     整租          7号线达官营   西城区天宁寺西里                 正规两居室    楼梯
# 124      转租     合租        望京西站13号线       香颂3期                正规次卧朝阳    电梯
# 125      转租     合租          8号线平西府   田园风光雅园东区             正规次卧，四室两卫    楼梯
#
#          楼层                 登记时间         预算               联系方式  \
# 0    24楼19层                 登记日期         价位               联系方式
# 7        2层  2022-03-01 00:00:00       2300    电话同微13050566120
# 8        17  2022-01-03 00:00:00       4200        18206681785
# 9        3楼  2022-01-03 00:00:00       2730  VX同电话：15311522713
# 10       2层  2022-01-17 00:00:00       1200   vx电话 17736573437
# ..      ...                  ...        ...                ...
# 121     20层  2022-03-01 00:00:00       6000       tcy425816 微信
# 122      2层  2022-03-01 00:00:00  2000/2500   grace304874709微信
# 123      5层  2022-03-01 00:00:00       5200      15001111201微信
# 124     10层  2022-03-02 00:00:00  2700-3000    15801260086微信同步
# 125      6层  2022-03-02 00:00:00       1900          S_pxy99_R
#
#                                                     备注
# 0                                                   备注
# 7           与房东签合同，押一付三，无中介费和服务费，水费已交，有5g网，房间采光好，整洁安静。
# 8                               与房东签合同，押一付三。无中介，已有无线网。
# 9        自如签的合同，放心入住，安全干净卫生，有无线网，合同2023年9月4号到期，因工作原因转租
# 10                     与房东签合同，已经押金了，无中介，有网。租期3.15-7.15
# ..                                                 ...
# 121                                         房东直租，无中介费。
# 122                     押一付一，全职妈妈房东直租，无中介费，可以看各种证件，好沟通
# 123                      押一付三，转租，余14个月，无中介费，如有需要可与房东直签
# 124              个人转租，房子新，装修精，个人刚租交完中介费、服务费。便宜转租，只需交租金
# 125  在地铁站一二百米的位置，1900一个月。已和房东商议好不要中介费，到期🉑️和直接与房东续签。...
#
# [114 rows x 11 columns]

# %% [markdown]
# ### filter price

# %%
def find_price(s: str) -> int:
    import re
    s = re.search(r'\d+', str(s))
    return int(s.group()) if s else 0

df['price_base'] = df['预算'].apply(find_price)
df = df.query("2000 <= price_base <= 3000")
df
# Out:
#     求整租／求合租  居室                      区域           居室.1                   一居室  \
# 7        转租  合租                 西二旗邓庄南路       唐家岭t09小区                    次卧
# 9        转租  合租          距离6号线田村地铁站269米         田村48号院     单间，正规三居室，其他两间都是女生
# 11       转租  合租                 10号线石榴庄        康泽园小区二期                  主卧独卫
# 12      招室友  合租                亦庄线小红门\n         鸿博家园二期              两室一厅飘窗主卧
# 14       房东  合租                西城右安门内大街        甲10号院6楼              三室一厅独卫独厨
# 19       转租  合租                  海淀区学院路  清华东路17号院农大家属院                   三居室
# 23       转租  合租               朝阳路 1号6号线          慈云寺北里               精装修朝南次卧
# 30       转租  合租                  昌平区回龙观         龙锦苑东一区               三居室，步梯，
# 32      招室友  合租                  昌平区回龙观          通达园小区              复试，主卧，朝南
# 34       房东  合租            1号线，石景山区鲁谷南路          六合园北区                  三室一厅
# 35       转租  合租                   朝阳酒仙桥          驼房营南里                  两室一厅
# 37       转租  合租                     天通苑         天通苑西二区                   大次卧
# 39       转租  合租             海淀区永丰南近16号线         永旺家园一区                  主卧朝南
# 41      招室友  合租              朝阳区柳芳地铁站附近           柳芳北里              两室一厅次卧朝东
# 43       转租  合租              昌平区霍营地铁站附近          华龙苑南里              两室一厅朝南主卧
# 44       转租  合租                  西城区陶然亭     半步桥13号院3号楼           三居，转租大主卧带阳台
# 45       转租  合租                 潘家园/十里河            华辉苑               四室一厅，次卧
# 47      NaN  合租              青年路国美第一城小区          国美第一城                    次卧
# 49       转租  合租                朝阳区垡头地铁站           翠城馨园                  主卧双窗
# 53       转租  合租               4号线义和庄地铁站         泰禾中央广场                    主卧
# 54       转租  合租           14号线望京、东湖渠地铁站         南湖东园一区                    次卧
# 32     步梯       6层  2022-01-10 00:00:00    2700/月，押一付一
# 34     电梯      20楼  2022-01-10 00:00:00    2600/月，押一付三
# 35     步梯       2楼  2022-01-10 00:00:00    3000╱月，押一付三
# 37     电梯       9楼  2022-01-10 00:00:00    2500/月，押一付三
# 39     电梯      14楼  2022-01-10 00:00:00    2850/月，押一付三
# 41     电梯      11楼  2022-01-12 00:00:00    3000/月，押一付三
# 43     步梯       6楼  2022-01-16 00:00:00    2900/月，押一付三
# 44     步梯  半地下，负一楼  2022-01-16 00:00:00      2360,押一付三
# 45     电梯      18楼  2022-01-17 00:00:00      2100，押一付一
# 47     电梯      12楼  5022-01-17 00:00:00      2600，押一付三
# 49     步梯       2楼  2022-01-17 00:00:00       2400押一付三
# 53     电梯       7楼  2022-01-24 00:00:00       2000押一付三
# 54     电梯       8楼  2022-02-07 00:00:00       2600押一付三
# 55     步梯       1楼  2022-02-07 00:00:00       2000押一付三
# 61     电梯      11楼  2022-02-07 00:00:00  2300.1200押一付三
# 63     电梯    2/15层  2022-02-07 00:00:00       3000押一付三
# 65     步梯       1楼  2022-02-07 00:00:00       2000押一付三
# 68     楼梯       2层  2022-02-07 00:00:00       2900押一付一
# 69     电梯    20/28  2022-02-07 00:00:00       2000押一付三
# 70     电梯    1-701  2022-02-07 00:00:00       2000押一付三
# 71     电梯       6层  2022-02-07 00:00:00       2500押一付三
# 72     电梯      11层  2022-02-08 00:00:00       2400押一付一
# 73     楼梯        4  2022-02-08 00:00:00           2500
# 76     电梯      19层  2022-02-14 00:00:00      2450，押一付三
# 77     楼梯       3层  2022-02-14 00:00:00       2200押一付六
# 91     楼梯    1层/2层            2022年2.21           2500
# 95     电梯   12/18层  2022-02-21 00:00:00      2200，押一付三
# 99     电梯     6/6层            2022年2月21      2700，押一付三
# 100    电梯   12/18层  2022-02-21 00:00:00      2300，押一付三
# 101    电梯    9/18层  2021-02-21 00:00:00       2100押一付三
# 102    电梯   24/26层  2022-02-21 00:00:00       2100押一付三
# 103    电梯    8/31层  2022-02-22 00:00:00       2200押一付三
# 104    楼梯     2/5层  2022-02-22 00:00:00       2790押一付三
# 106    电梯      10层  2022-02-28 00:00:00       2200押一付三
# 107    楼梯        6            2022/2／28       2800押一付一
# 108    电梯      10层  2022-02-28 00:00:00       2100押一付三
# 112    楼梯       2层            2022年2月28       3000押一付三
# 115    电梯       4层  2022-03-01 00:00:00  2000元押一付三 无中介
# 117    电梯       2层  2022-03-01 00:00:00           2300
# 118    电梯      23层  2022-03-01 00:00:00           3000
# 119    楼梯       5层  2022-03-01 00:00:00           3000
# 122    电梯       2层  2022-03-01 00:00:00      2000/2500
# 124    电梯      10层  2022-03-02 00:00:00      2700-3000
#
#                           联系方式  \
# 7              电话同微13050566120
# 9            VX同电话：15311522713
# 11                 18101080610
# 12            18611963994（同wx）
# 14                    94522286
# 19            18731745417（同vx）
# 23              微信：15532159982
# 30            电话同微 15738739350
# 32            电话同微：18283765946
# %% [markdown]
# ### call gaode api and update distances

# %%
df2 = df2.copy()
df2["work_minutes"] = df2['居室.1'].apply(lambda x: calc_transit_dis(x, TARGET_ADDRESS))
df2
# Out:
# INFO:root:calc_work_dis: from_address: 87号楼, to_address: 源创空间大厦
# INFO:root:calc_work_dis: from_address: 友谊嘉园二期, to_address: 源创空间大厦
# INFO:root:fetching loc of 友谊嘉园二期 from gaode api
# INFO:root:calc_work_dis: from_address: 住欣家园, to_address: 源创空间大厦
# INFO:root:fetching loc of 住欣家园 from gaode api
# INFO:root:calc_work_dis: from_address: 天通西苑, to_address: 源创空间大厦
# INFO:root:fetching loc of 天通西苑 from gaode api
# INFO:root:calc_work_dis: from_address: 华源一里, to_address: 源创空间大厦
# INFO:root:fetching loc of 华源一里 from gaode api
# INFO:root:calc_work_dis: from_address: 泰福苑二区, to_address: 源创空间大厦
# INFO:root:fetching loc of 泰福苑二区 from gaode api
# INFO:root:calc_work_dis: from_address: 云趣园二区, to_address: 源创空间大厦
# INFO:root:fetching loc of 云趣园二区 from gaode api
# INFO:root:calc_work_dis: from_address: 新建村二期高层, to_address: 源创空间大厦
# INFO:root:fetching loc of 新建村二期高层 from gaode api
# INFO:root:calc_work_dis: from_address: 吉晟别墅, to_address: 源创空间大厦
# INFO:root:fetching loc of 吉晟别墅 from gaode api
# INFO:root:calc_work_dis: from_address: tbd万科住总, to_address: 源创空间大厦
# INFO:root:fetching loc of tbd万科住总 from gaode api
# INFO:root:calc_work_dis: from_address: 百环花园, to_address: 源创空间大厦
# INFO:root:fetching loc of 百环花园 from gaode api
# INFO:root:calc_work_dis: from_address: 惠新西街小区, to_address: 源创空间大厦
# INFO:root:fetching loc of 惠新西街小区 from gaode api
# INFO:root:calc_work_dis: from_address: 京通苑, to_address: 源创空间大厦
# INFO:root:fetching loc of 京通苑 from gaode api
# INFO:root:calc_work_dis: from_address: 香颂3期, to_address: 源创空间大厦
# INFO:root:fetching loc of 香颂3期 from gaode api
#     求整租／求合租  居室                      区域        居室.1                   一居室  \
# 7        转租  合租                 西二旗邓庄南路    唐家岭t09小区                    次卧
# 9        转租  合租          距离6号线田村地铁站269米      田村48号院     单间，正规三居室，其他两间都是女生
# 11       转租  合租                 10号线石榴庄     康泽园小区二期                  主卧独卫
# 12      招室友  合租                亦庄线小红门\n      鸿博家园二期              两室一厅飘窗主卧
# 14       房东  合租                西城右安门内大街     甲10号院6楼              三室一厅独卫独厨
# 23       转租  合租               朝阳路 1号6号线       慈云寺北里               精装修朝南次卧
# 34       房东  合租            1号线，石景山区鲁谷南路       六合园北区                  三室一厅
# 35       转租  合租                   朝阳酒仙桥       驼房营南里                  两室一厅
# 37       转租  合租                     天通苑      天通苑西二区                   大次卧
# 41      招室友  合租              朝阳区柳芳地铁站附近        柳芳北里              两室一厅次卧朝东
# 44       转租  合租                  西城区陶然亭  半步桥13号院3号楼           三居，转租大主卧带阳台
# 37     电梯       9楼  2022-01-10 00:00:00    2500/月，押一付三
# 41     电梯      11楼  2022-01-12 00:00:00    3000/月，押一付三
# 44     步梯  半地下，负一楼  2022-01-16 00:00:00      2360,押一付三
# 45     电梯      18楼  2022-01-17 00:00:00      2100，押一付一
# 47     电梯      12楼  5022-01-17 00:00:00      2600，押一付三
# 49     步梯       2楼  2022-01-17 00:00:00       2400押一付三
# 53     电梯       7楼  2022-01-24 00:00:00       2000押一付三
# 54     电梯       8楼  2022-02-07 00:00:00       2600押一付三
# 63     电梯    2/15层  2022-02-07 00:00:00       3000押一付三
# 65     步梯       1楼  2022-02-07 00:00:00       2000押一付三
# 68     楼梯       2层  2022-02-07 00:00:00       2900押一付一
# 69     电梯    20/28  2022-02-07 00:00:00       2000押一付三
# 70     电梯    1-701  2022-02-07 00:00:00       2000押一付三
# 71     电梯       6层  2022-02-07 00:00:00       2500押一付三
# 72     电梯      11层  2022-02-08 00:00:00       2400押一付一
# 73     楼梯        4  2022-02-08 00:00:00           2500
# 76     电梯      19层  2022-02-14 00:00:00      2450，押一付三
# 77     楼梯       3层  2022-02-14 00:00:00       2200押一付六
# 99     电梯     6/6层            2022年2月21      2700，押一付三
# 100    电梯   12/18层  2022-02-21 00:00:00      2300，押一付三
# 101    电梯    9/18层  2021-02-21 00:00:00       2100押一付三
# 102    电梯   24/26层  2022-02-21 00:00:00       2100押一付三
# 103    电梯    8/31层  2022-02-22 00:00:00       2200押一付三
# 104    楼梯     2/5层  2022-02-22 00:00:00       2790押一付三
# 106    电梯      10层  2022-02-28 00:00:00       2200押一付三
# 107    楼梯        6            2022/2／28       2800押一付一
# 108    电梯      10层  2022-02-28 00:00:00       2100押一付三
# 112    楼梯       2层            2022年2月28       3000押一付三
# 115    电梯       4层  2022-03-01 00:00:00  2000元押一付三 无中介
# 117    电梯       2层  2022-03-01 00:00:00           2300
# 118    电梯      23层  2022-03-01 00:00:00           3000
# 119    楼梯       5层  2022-03-01 00:00:00           3000
# 122    电梯       2层  2022-03-01 00:00:00      2000/2500
# 124    电梯      10层  2022-03-02 00:00:00      2700-3000
#
#                           联系方式  \
# 7              电话同微13050566120
# 9            VX同电话：15311522713
# 11                 18101080610
# 12            18611963994（同wx）
# 14                    94522286
# 23              微信：15532159982
# 34             电话微信18601203454
# 35               电话18701815919
# 37            电话同微信15001272928
# 41            电话同微信15205217865
# 44            电话同微信13591711214
# 45             15133166839，同微信
# 47                '13070198955
# 49                 15176733086
# 53            17812037273(同微信)
# 54             17367941127微信同步
# 63               微信:q609010297
# 65               微信17320215573
# 68              微信：15122161813
# 69               微信：1844457056
# 70                 18510102073
# 71              微信 18679229291
# 72                 微信418130452
# 73               vx：zcc_Lesley
# 76               电话18304096187
# 77                 13522998456
# 99             18679229291同微信号
# 100            13563012070微信同号
# 101            13135132672微信同号
# 102    18612987358微信号529579829
# 103            15136400403微信同号
# 104            13391991295微信同号
# 106            13520898418微信同号
# 107              yy18609334715
# 101                     次卧，个人转租，无中介费，软件园附近上班的很方便20分钟路程        2100
# 102                        次卧，个人合租，无中介费，附近长嬴天街商圈生活比较方便        2100
# 103                          朝南20+平次卧，采光好，近地铁步行十分钟无中介费        2200
# 104  18平次卧带阳台，精装修，干净，个人转租无中介费；可做饭，包网费保洁日常修理，配管家；周边设...        2790
# 106             次卧。房东直租，仅限女生，不养宠物，不抽烟，爱干净，作息规律，不带朋友回家。        2200
# 107                                   主卧独卫，房子从房东整租下来的         2800
# 108  客厅隔间，面积比房间里的主卧还稍微大一点，朝南，5—10分钟到地铁站，合约到2022年7月7...        2100
# 112                           距离13号线地铁回龙观站 ，8号线育新站500米        3000
# 115  下楼有美食街很多饭店，外卖多，金拱门有，肯德基也要开了，很多好吃的。十一点还有小吃摊很爽，楼...        2000
# 117         与房东签合同，押一付三，无中介费和服务费，水费已交，有5g网，房间采光好，整洁安静。        2300
# 118  中介费服务费已交，预计4月开始租，转租到六月底。之后也可以直接和中介签约。离地铁非常近，很方...        3000
# 119                主卧，离惠新西街南口北口，都挺近。到4月底，到期可续。无中介费，好沟通        3000
# 122                     押一付一，全职妈妈房东直租，无中介费，可以看各种证件，好沟通        2000
# 124              个人转租，房子新，装修精，个人刚租交完中介费、服务费。便宜转租，只需交租金        2700
#
#      work_minutes
# 7             150
# 9             131
# 11            106
# 12             92
# 14            117
# 23             55
# 34            128
# 35             86
# 37             97
# 41             66
# 44            112
# 45             71
# 47             47
# 49             76
# 53            102
# 54            100
# 63             72
# 65            176
# 68             67
# 69            128
# 70            102
# 71            133
# 72             42
# 73            116
# 76            123
# 77            126
# 99            136
# 100           999
# 101           166
# 102            80
# 103           109
# 104           115
# 106            68
# 107           153
# 108           103
# 112           148
# 115           115
# 117           150
# 118            63
# 119           105
# 122            67
# 124           132

# %% [markdown]
# ### drop distance too far

# %%
df2 = df2.query("work_minutes < 60").copy()

# %% [markdown]
# ### rank

# %%
df2['score'] = df2['price_base'] * df2['work_minutes']
df3 = df2
df3.sort_values(by=["score"], ascending=True, inplace=True)
df3
# Out:
#    求整租／求合租  居室          区域    居室.1      一居室 步梯／电梯     楼层                 登记时间  \
# 72      转租  合租       朝阳青年路  珠江罗马嘉园       次卧    电梯    11层  2022-02-08 00:00:00
# 23      转租  合租   朝阳路 1号6号线   慈云寺北里  精装修朝南次卧    电梯  8/28层  2022-01-03 00:00:00
# 47     NaN  合租  青年路国美第一城小区   国美第一城       次卧    电梯    12楼  5022-01-17 00:00:00
#
#            预算            联系方式  \
# 72   2400押一付一     微信418130452
# 23       2000  微信：15532159982
# 47  2600，押一付三    '13070198955
#
#                                                    备注  price_base  \
# 72    没有中介费，三月初可以入住，可以和中介重新签合同，紧挨朝悦，青年路地铁，想要跟朋友合租所以转租        2400
# 23  与中介签合同，押一付三，无中介费，无服务费。高层正南次卧。朝阳路黄金地段，临近CBD，国贸直...        2000
# 47                                           新客户完成：5家        2600
#
#     work_minutes   score
# 72            42  100800
# 23            55  110000
# 47            47  122200
